# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# yahoo finance
import yfinance as yf 



# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 1.0.1

# %%
# df: dataframe *args: column's names.
def graficar(df, *args):
    plt.figure(figsize=[15,10])
    plt.grid(True)
    for x in args:
        plt.plot(df[x],label=x)
    plt.legend(loc=2)

# %%
ticker = 'GGAL.BA'

# %%
galb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-68030eba0394> in <module>
# ----> 1 gal
#
# NameError: name 'gal' is not defined

# %%
galba.tail()
# Out:
#                   Open        High         Low       Close   Volume
# Date
# 2020-08-28  126.150002  133.500000  126.150002  133.050003  3297567
# 2020-08-31  132.000000  135.000000  129.899994  133.350006  3002832
# 2020-09-01  136.000000  137.000000  129.100006  131.949997  2285759
# 2020-09-02  129.500000  129.699997  124.750000  125.849998  3311816
# 2020-09-03  128.800003  130.000000  127.300003  127.300003   514007

# %%
def graficar(df, *args):
    plt.figure(figsize=[15,10])
    plt.grid(True)
    for x in args:
        plt.plot(df[x],label=x)
    plt.legend(loc=2)

# %%
graficar(galba,'Close')
