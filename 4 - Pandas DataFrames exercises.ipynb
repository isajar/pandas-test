# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas DataFrame exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 1.0.1

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame creation

# %% [markdown]
# ### Create an empty pandas DataFrame

# %%
# your code goes here
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame(data=[None],
             index=[None],
             columns=[None])

# %% [markdown]
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
# your code goes here
df = pd.DataFrame({
    'name':['Spider-Man','Captain America','Wolverine'],
    'gender':['male', 'male', 'male'],
    'dof': [1962,1941,1974]
})
df
# Out:
#               name gender   dof
# 0       Spider-Man   male  1962
# 1  Captain America   male  1941
# 2        Wolverine   male  1974

# %%
marvel_df = pd.DataFrame(data=marvel_data)

marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add column names to the `marvel_df`

# %%
# your code goes here
marvel_df.columns=['name','gender','dof']
marvel_df
# Out:
#                 name  gender   dof
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
col_names = ['name', 'sex', 'first_appearance']

marvel_df.columns = col_names
marvel_df
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# 19            Vision    male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add index names to the `marvel_df` (use the character name as index)

# %%
# your code goes here
marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# Hank Pym                  Hank Pym    male              1962
# Scarlet Witch        Scarlet Witch  female              1964
# Wasp                          Wasp  female              1963
# Black Widow            Black Widow  female              1964
# Vision                      Vision    male              1968

# %%
marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# Hank Pym                  Hank Pym    male              1962
# Scarlet Witch        Scarlet Witch  female              1964
# Wasp                          Wasp  female              1963
# Black Widow            Black Widow  female              1964
# Vision                      Vision    male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop the name column as it's now the index

# %%
# your code goes here
marvel_df.drop(columns=['name'])
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
#marvel_df = marvel_df.drop(columns=['name'])
marvel_df = marvel_df.drop(['name'], axis=1)
marvel_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-2314b6adc0fc> in <module>
#       1 #marvel_df = marvel_df.drop(columns=['name'])
# ----> 2 marvel_df = marvel_df.drop(['name'], axis=1)
#       3 marvel_df
#
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['name'] not found in axis"

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop 'Namor' and 'Hank Pym' rows

# %%
# your code goes here
marvel_df.info()
marvel_df.head()
marvel_df.index
marvel_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, Spider-Man to Vision
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   gender  18 non-null     object
#  1   dof     18 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.0+ KB
# (18, 2)

# %%
marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)
marvel_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-b4073a997292> in <module>
# ----> 1 marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)
#       2 marvel_df
#
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['Namor' 'Hank Pym'] not found in axis"

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ### Show the first 5 elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[0:5, 1].to_frame()
# Out:
#                   dof
# name
# Spider-Man       1962
# Captain America  1941
# Wolverine        1974
# Iron Man         1963
# Thor             1963

# %%
#marvel_df.loc[['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor'], :] # bad!
#marvel_df.loc['Spider-Man': 'Thor', :]
#marvel_df.iloc[0:5, :]
#marvel_df.iloc[0:5,]
marvel_df.iloc[:5,]
#marvel_df.head()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the last 5 elements on `marvel_df`

# %%
# your code goes here
i_last_5 = len(marvel_df.index) - 5
marvel_df.iloc[i_last_5:-1, 0].to_frame()
marvel_df.iloc[-5:,0]

# %%
marvel_df.tail(7)
# Out:
#                           name     sex  first_appearance
# name
# Daredevil            Daredevil    male              1964
# Doctor Strange  Doctor Strange    male              1963
# Hank Pym              Hank Pym    male              1962
# Scarlet Witch    Scarlet Witch  female              1964
# Wasp                      Wasp  female              1963
# Black Widow        Black Widow  female              1964
# Vision                  Vision    male              1968

# %%
#marvel_df.loc[['Hank Pym', 'Scarlet Witch', 'Wasp', 'Black Widow', 'Vision'], :] # bad!
#marvel_df.loc['Hank Pym':'Vision', :]
marvel_df.iloc[-5:,]
#marvel_df.tail()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show just the sex of the first 5 elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[:5,]['sex']
# Out:
# name
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: sex, dtype: object

# %%
marvel_df.loc[:'Thor','sex']
# Out:
# name
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: sex, dtype: object

# %%
marvel_df.head(7)
# Out:
#                               name   sex  first_appearance
# name
# Spider-Man              Spider-Man  male              1962
# Captain America    Captain America  male              1941
# Wolverine                Wolverine  male              1974
# Iron Man                  Iron Man  male              1963
# Thor                          Thor  male              1963
# Thing                        Thing  male              1961
# Mister Fantastic  Mister Fantastic  male              1961

# %%
marvel_df
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# Hank Pym                  Hank Pym    male              1962
# Scarlet Witch        Scarlet Witch  female              1964
# Wasp                          Wasp  female              1963
# Black Widow            Black Widow  female              1964
# Vision                      Vision    male              1968

# %%
#marvel_df.iloc[:5,]['sex'].to_frame()
marvel_df.iloc[:5,].sex.to_frame()
#marvel_df.head().sex.to_frame()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first_appearance of all middle elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[1:-1]['first_appearance'].to_frame()
# Out:
#                   first_appearance
# name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Namor                         1939
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Hank Pym                      1962
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %%
marvel_df.iloc[1:-1,].first_appearance.to_frame()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first and last elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[[0,-1]]
# Out:
#                   name   sex  first_appearance
# name
# Spider-Man  Spider-Man  male              1962
# Vision          Vision  male              1968

# %%
marvel_df.loc[['Spider-Man', 'Vision']]
# Out:
#                   name   sex  first_appearance
# name
# Spider-Man  Spider-Man  male              1962
# Vision          Vision  male              1968

# %%
#marvel_df.iloc[[0, -1],][['sex', 'first_appearance']]
marvel_df.iloc[[0, -1],]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame manipulation and operations

# %% [markdown]
# ### Modify the `first_appearance` of 'Vision' to year 1964

# %%
# your code goes here
marvel_df.loc['Vision','first_appearance'] = 1964
marvel_df.loc['Vision','first_appearance']
# Out:
# 1964

# %%
marvel_df.loc['Vision', 'first_appearance'] = 1964

marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
# your code goes here
marvel_df['years_since'] = 2020 - marvel_df['first_appearance']
marvel_df
# Out:
#                               name     sex  first_appearance  years_since
# name
# Spider-Man              Spider-Man    male              1962           58
# Captain America    Captain America    male              1941           79
# Wolverine                Wolverine    male              1974           46
# Iron Man                  Iron Man    male              1963           57
# Thor                          Thor    male              1963           57
# Thing                        Thing    male              1961           59
# Mister Fantastic  Mister Fantastic    male              1961           59
# Hulk                          Hulk    male              1962           58
# Beast                        Beast    male              1963           57
# Invisible Woman    Invisible Woman  female              1961           59
# Storm                        Storm  female              1975           45
# Namor                        Namor    male              1939           81
# Hawkeye                    Hawkeye    male              1964           56
# Daredevil                Daredevil    male              1964           56
# Doctor Strange      Doctor Strange    male              1963           57
# Hank Pym                  Hank Pym    male              1962           58
# Scarlet Witch        Scarlet Witch  female              1964           56
# Wasp                          Wasp  female              1963           57
# Black Widow            Black Widow  female              1964           56
# Vision                      Vision    male              1964           56

# %%
marvel_df['years_since'] = 2018 - marvel_df['first_appearance']

marvel_df

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame boolean arrays (also called masks)

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
# your code goes here
femaleMask = marvel_df.iloc[:].sex == 'female'
marvel_df[femaleMask]
# Out:
#                             name     sex  first_appearance  years_since
# name
# Invisible Woman  Invisible Woman  female              1961           59
# Storm                      Storm  female              1975           45
# Scarlet Witch      Scarlet Witch  female              1964           56
# Wasp                        Wasp  female              1963           57
# Black Widow          Black Widow  female              1964           56

# %%
mask = marvel_df['sex'] == 'female'

mask

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the male characters

# %%
# your code goes here
maleMask = marvel_df['sex'] == 'male'
maleMask2 = ~ femaleMask
maleMask2
# Out:
# name
# Spider-Man           True
# Captain America      True
# Wolverine            True
# Iron Man             True
# Thor                 True
# Thing                True
# Mister Fantastic     True
# Hulk                 True
# Beast                True
# Invisible Woman     False
# Storm               False
# Namor                True
# Hawkeye              True
# Daredevil            True
# Doctor Strange       True
# Hank Pym             True
# Scarlet Witch       False
# Wasp                False
# Black Widow         False
# Vision               True
# Name: sex, dtype: bool

# %%
marvel_df.loc[~maleMask].first_appearance.to_frame()
# Out:
#                  first_appearance
# name
# Invisible Woman              1961
# Storm                        1975
# Scarlet Witch                1964
# Wasp                         1963
# Black Widow                  1964

# %%
mask = marvel_df['sex'] == 'male'

marvel_df[mask]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` after 1970

# %%
# your code goes here
after1970_mask = marvel_df.loc[:].first_appearance > 1970
after1970_mask
marvel_df.loc[after1970_mask,].first_appearance.to_frame()
# Out:
#            first_appearance
# name
# Wolverine              1974
# Storm                  1975

# %%
mask = marvel_df['first_appearance'] > 1970

marvel_df[mask]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the female characters with `first_appearance` after 1970

# %%
# your code goes here
mask = femaleMask & after1970_mask
mask
marvel_df.loc[mask]
# Out:
#         name     sex  first_appearance  years_since
# name
# Storm  Storm  female              1975           45

# %%
mask = (marvel_df['sex'] == 'female') & (marvel_df['first_appearance'] > 1970)

marvel_df[mask]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame summary statistics

# %% [markdown]
# ### Show basic statistics of `marvel_df`

# %%
# your code goes here
marvel_df.describe()
# Out:
#        first_appearance  years_since
# count         20.000000    20.000000
# mean        1961.650000    58.350000
# std            8.298859     8.298859
# min         1939.000000    45.000000
# 25%         1961.750000    56.000000
# 50%         1963.000000    57.000000
# 75%         1964.000000    58.250000
# max         1975.000000    81.000000

# %%
marvel_df.describe()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the mean value of `first_appearance`

# %%
# your code goes here
marvel_df.loc[:,].first_appearance.mean()
# Out:
# 1961.65

# %%
#np.mean(marvel_df.first_appearance)
marvel_df.first_appearance.mean()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
# your code goes here
min_first_ap = marvel_df.loc[:,].first_appearance.min()
min_first_ap
# Out:
# 1939

# %%
#np.min(marvel_df.first_appearance)
marvel_df.first_appearance.min()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with the min value of `first_appearance`

# %%
# your code goes here
mask1 = marvel_df.loc[:,].first_appearance == min_first_ap
marvel_df.loc[mask1]
# Out:
#         name   sex  first_appearance  years_since
# name
# Namor  Namor  male              1939           81

# %%
mask = marvel_df['first_appearance'] == marvel_df.first_appearance.min()
marvel_df[mask]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame basic plottings

# %% [markdown]
# ### Reset index names of `marvel_df`

# %%
# your code goes here
marmarvel_df.reset_index()
marvel_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-7797ff42e4ef> in <module>
#       1 # your code goes here
# ----> 2 marvel_df.reset_index()
#       3 marvel_df
#
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4602                 # to ndarray and maybe infer different dtype
#    4603                 level_values = _maybe_casted_values(lev, lab)
# -> 4604                 new_obj.insert(0, name, level_values)
#    4605
#    4606         new_obj.index = new_index
#
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3494         self._ensure_valid_index(value)
#    3495         value = self._sanitize_column(column, value, broadcast=False)
# -> 3496         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3497
#    3498     def assign(self, **kwargs) -> "DataFrame":
#
# /usr/local/lib/python3.8/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
#    1172             # Should this be a different kind of error??
# -> 1173             raise ValueError(f"cannot insert {item}, already exists")
#    1174
#    1175         if not isinstance(loc, int):
#
# ValueError: cannot insert name, already exists

# %%
marvel_df = marvel_df.reset_index()

marvel_df
# Out:
#                 name     sex  first_appearance  years_since
# 0         Spider-Man    male              1962           58
# 1    Captain America    male              1941           79
# 2          Wolverine    male              1974           46
# 3           Iron Man    male              1963           57
# 4               Thor    male              1963           57
# 5              Thing    male              1961           59
# 6   Mister Fantastic    male              1961           59
# 7               Hulk    male              1962           58
# 8              Beast    male              1963           57
# 9    Invisible Woman  female              1961           59
# 10             Storm  female              1975           45
# 11             Namor    male              1939           81
# 12           Hawkeye    male              1964           56
# 13         Daredevil    male              1964           56
# 14    Doctor Strange    male              1963           57
# 15          Hank Pym    male              1962           58
# 16     Scarlet Witch  female              1964           56
# 17              Wasp  female              1963           57
# 18       Black Widow  female              1964           56
# 19            Vision    male              1964           56

# %%
marvel_df = marvel_df.drop('name',axis=1)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot the values of `first_appearance`

# %%
# your code goes here

# %%
#plt.plot(marvel_df.index, marvel_df.first_appearance)
marvel_df.first_appearance.plot()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot a histogram (plot.hist) with values of `first_appearance`

# %%
# your code goes here
marvel_df['first_appearance'].plot.hist()

# %%
plt.hist(marvel_df.first_appearance)
# Out:
# (array([ 2.,  0.,  0.,  0.,  0.,  0., 16.,  0.,  0.,  2.]),
#  array([1939. , 1942.6, 1946.2, 1949.8, 1953.4, 1957. , 1960.6, 1964.2,
#         1967.8, 1971.4, 1975. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
